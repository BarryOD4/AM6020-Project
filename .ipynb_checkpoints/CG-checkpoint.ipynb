# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def alph(r, d, A):
    """ Calculates learning rate,
    
    """
    top = r.T @ r
    bottom = d.T @ A @ d
    
    return top/bottom

def bet(rk, rkp1):
    """ Constructs Gram-Schmidt constant
    from current and previous residuals 
    """
    
    top = rkp1.T @ rkp1
    bottom = rk.T @ rk
    
    return top/bottom

# %%
def CGM(A, b, x0, accuracy=0.00001):
    """ Utilises the Conjugate Gradient Method to obtain the minimum point
    on a 2d-surface
    
    IN:  A  := numpy array, positive-definite n x n array
         b  := numpy array, scalar vector n x 1 array
         x0 := numpy array, initial guess vector n x 1 array
         accuracy := float, to what degree of accuracy should the result be
    
    OUT: xpk1 := numpy array, position of minimum of 2d surface, 2 x 1 array
    
    """
    
    rkp1 = b - A @ x0 # = r0
    dkp1 = rkp1
    xkp1 = x0
    
    path = x0

    numiter = 0

    while np.all(np.abs(rkp1) < accuracy) != True and numiter < 1000:

        numiter += 1
        alphak = alph(rkp1,dkp1,A)

        xkp1 = xkp1 + alphak * dkp1
        rk = rkp1
        rkp1 = rkp1 - alphak * np.dot(A, dkp1)

        betak = bet(rk,rkp1)

        dkp1 = rkp1 + betak * dkp1
        
        path = np.concatenate((path, xkp1), axis=1)
    
    
    return xkp1, path, numiter #x,y)

# %%
## Using values from
##  https://www.cs.cmu.edu/~quake-papers/painless-conjugate-gradient.pdf
## Expected outcome; xkp1 = [[2],[-2]]

A = np.array([[3,2],[2,6]])
b = np.array([[2],[-8]])

x0 = np.array([[-2],[-2]])

xkp1, path, n = CGM(A, b, x0)

print(xkp1)
# Out:
# [[ 2.]
#  [-2.]]

# %%
def fx(A,b,x1i,x2i):
    x = np.array([[x1i],[x2i]])
    
    part_one= x.T @ A @ x
    part_two = b.T @ x
    
    z = 0.5 * part_one - part_two
    
    return z[0][0]

# %%
def CGMconplot(A, b, x0, lims, spaces=0.05, accuracy=0.0001):
    
    x1 = np.arange(-lims, lims, spaces)
    X1, X2 = np.meshgrid(x1, x1)
    
    Z = a = np.zeros(shape=(x1.size,x2.size))
    for i in range(x1.size):
        for j in range(x2.size):
            val = fx(A,b,x1[i],x2[j])
            Z[i][j] = val

    zs = Z.reshape(X1.shape)
    
    xkp1, path, n = CGM(A, b, x0)
    
    plt.contour(X2, X1, zs)
    plt.plot(path[0], path[1], 'k*-', label='Path')
    plt.plot(path[0][0], path[1][0], 'bd', markersize=10, label='Start')
    plt.plot(xkp1[0], xkp1[1], 'rs', markersize=7, label='End')
    plt.legend()
    plt.show()
    
    print(n, path)

# %%
x1 = x2 =  np.arange(-10.0, 10.0, 0.05)

# %%
X1, X2 = np.meshgrid(x1, x2)
Z = a = np.zeros(shape=(x1.size,x2.size))
for i in range(x1.size):
    for j in range(x2.size):
        val = fx(A,b,x1[i],x2[j])
        Z[i][j] = val

zs = Z.reshape(X1.shape)

# %%
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X1, X2, zs)
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('Z')
plt.show()

# %%
xkp1[1]
# Out:
# array([-2.])

# %%
A = np.array([[3,1],[2,10]])
b = np.array([[2],[-8]])
print(np.all(np.linalg.eigvals(A) > 0))
x0 = np.array([[-5],[-10]])

CGMconplot(A, b, x0, 10)
# Out:
# True
# 1000 [[ -5.          -2.37449886   1.08702146 ...   0.99642012   0.99641173
#     0.99640365]
#  [-10.          -0.08144014  -0.67125226 ...  -0.99981748  -0.99980037
#    -0.99978337]]

# %%
np.all(np.linalg.eigvals(A) > 0)
# Out:
# True

# %%
A = np.array([[2,-1,0],[-1,2,-1],[0,-1,2]])

b = np.array([[2],[-1],[0]])

x0 = np.array([[2],[-1],[0]])
x, n = CGM(A, b, x0)

A @ x - b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8208/2373037204.py in <module>
#       4
#       5 x0 = np.array([[2],[-1],[0]])
# ----> 6 x, n = CGM(A, b, x0)
#       7
#       8 A @ x - b
#
# ValueError: too many values to unpack (expected 2)

# %%
n
